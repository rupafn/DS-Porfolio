# %%
import pandas as pd
import numpy as np
import os
from PIL import Image

# %% [markdown]
# # Separate dataset into test, train and validation set

# %%
count = 0
for (path, foldername, filenames) in os.walk('Datasets'):
    print(foldername)
    print('-----')
    for file in filenames:
        print(path+'/'+file)
        im = Image.open(path+'/'+file)
        
#     print(count,foldername,path,len(filenames))
# Out:
# ['Nematodes', 'Normal', 'Bacteria', 'Fungi', 'Virus']
# -----
# []
# -----
# Datasets/Nematodes/0e143d33-adc0-41af-92e2-d0bb712d7b72___FAM_B.Rot 5047.JPG
# Datasets/Nematodes/1d3c0f3d-1b66-4cfc-b67b-af9760864e99___FAM_B.Rot 3317.JPG
# Datasets/Nematodes/0cb269dc-10d1-45e6-b0d3-f96572fce674___FAM_B.Rot 5052.JPG
# Datasets/Nematodes/0e7726c0-a309-4194-b2e6-d0e33af39373___FAM_B.Rot 0530.JPG
# Datasets/Nematodes/0b11ac6a-9e24-4d9c-bbe9-e180eb81ff38___FAM_B.Rot 0581.JPG
# Datasets/Nematodes/1c2b4d6c-dc3d-4913-b98f-2da54c4f6614___FAM_B.Rot 3602.JPG
# Datasets/Nematodes/0bc6da94-2f94-4e4f-8858-b1a855dffbdf___FAM_B.Rot 3420.JPG
# Datasets/Nematodes/1ccd890e-9e06-44cf-8495-8f229e7bb89b___FAM_B.Rot 3614.JPG
# Datasets/Nematodes/0aff8add-93ad-4099-97ae-23515744e620___FAM_B.Rot 0748.JPG
# Datasets/Nematodes/0b9d95bb-51c7-40f1-8a4b-f9838becb418___FAM_B.Rot 0493.JPG
# Datasets/Nematodes/0a31549c-8adb-4acc-bab2-a0954f063054___FAM_B.Rot 0687.JPG
# ...
